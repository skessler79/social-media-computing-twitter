# %%
import pandas as pd
import json

# %%
# USERNAME = "TheBabylonBee"
# USERNAME = "HardDriveMag"
# USERNAME = "TheOnion"
USERNAME = "Reductress"

# %%
df = pd.read_json(f"output_selenium_{USERNAME}.json", orient="index", convert_dates=True)

# %%
df = df.reset_index().rename(columns={'index': 'link'})

# %%
df
# Out:
#                                                   link  \
# 0    https://twitter.com/Reductress/status/16744181...
# 1    https://twitter.com/Reductress/status/16741609...
# 2    https://twitter.com/Reductress/status/16741460...
# 3    https://twitter.com/Reductress/status/16741308...
# 4    https://twitter.com/Reductress/status/16741160...
# ..                                                 ...
# 818  https://twitter.com/Reductress/status/16403986...
# 819  https://twitter.com/Reductress/status/16403835...
# 820  https://twitter.com/Reductress/status/16403684...
# 821  https://twitter.com/Reductress/status/16403532...
# 822  https://twitter.com/Reductress/status/16401289...
#
#                                                   text  \
# 0    Slack Introduces New Status Telling Boss You’r...
# 1    QUIZ: Is He Cute or Did He Just Agree With You...
# 2    Woman Wraps Self in Shiny Foil Blanket After F...
# 3    This Woman’s Eyebrows Are Neither Sisters Nor ...
# ...
